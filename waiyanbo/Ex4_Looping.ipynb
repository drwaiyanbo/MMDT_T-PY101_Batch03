# %% [markdown]
# <a href="https://colab.research.google.com/github/drwaiyanbo/MMDT_T-PY101_Batch03/blob/main/waiyanbo/Ex4_Looping.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# The exercises are extracted from A_Practical_Introduction_to_Python_Programming_Heinold.pdf

# %% [markdown]
# Ex 1: Write a program that uses a while loop (not a for loop) to read through a string and print
# the characters of the string one-by-one on separate lines.

# %%
 text = str(input("Enter the text"))

 i = 0
 while i < len(text):
    print(text[i])
    i += 1
# Out:
# Enter the textletter
# l
# e
# t
# t
# e
# r

# %% [markdown]
# Ex 2: A good program will make sure that the data its users enter is valid. Write a program that
# asks the user for a weight and converts it from kilograms to pounds. Whenever the user
# enters a weight below 0, the program should tell them that their entry is invalid and then ask
# them again to enter a weight. [Hint: Use a while loop, not an if statement].

# %%
# input from user
weight_kg = float(input("Enter weight in kilograms: "))

# start the loop
while weight_kg < 0:
    print("Invalid entry. Weight cannot be negative.")
    weight_kg = float(input("Enter weight in kilograms: "))

# calculate conversion
weight_lbs = weight_kg * 2.20462
print("Weight in pounds:", weight_lbs)

# final print result
print(f"Weight in punds: {weight_lbs:.2f}")
# Out:
# Enter weight in kilograms: 78
# Weight in pounds: 171.96035999999998
# Weight in punds: 171.96

# %% [markdown]
# Ex 3: Write a program that allows the user to enter any number of test scores. The user indicates
# they are done by entering in a negative number. Print how many of the scores are A’s (90 or
# above). Also print out the average

# %%
# define variables
total_sum = 0
total_count = 0
a_count = 0

print("Enter test scores. Enter a negative number to stop.")

# User input for first score
score = float(input("Enter test score: "))

# Loop as long as score is negative
while score >= 0:
  total_sum = total_sum + score
  total_count = total_count + 1

  # check if score is "A"
  if score >= 90:
    a_count = a_count + 1

  # next score
  score = float(input("Enter test score: "))


# Calculate Average
print (f"Average: {total_sum/total_count}")
print (f"Number of A's: {a_count}")
print (f"Total number of scores: {total_count}")
# Out:
# Enter test scores. Enter a negative number to stop.
# Enter test score: 10
# Enter test score: 80
# Enter test score: 90
# Enter test score: 95
# Enter test score: 92
# Enter test score: 20
# Enter test score: -1
# Average: 64.5
# Number of A's: 3
# Total number of scores: 6

# %% [markdown]
# Ex 4: Write a program that asks the user for a string and a letter. Using a for loop, the
# program should print the index of the first occurrence of that letter and a message if the
# string does not contain the letter.

# %%
# input from user
text = input("Enter a string: ")
target_letter = input("Enter a letter to find: ")

# false variable
found = False

# looping for found true
for i in range(len(text)):
  if target_letter == text[i]:
    print(f"First occurence is at index: {i}")
    found = True
    break

# look for found false:
if not found:
  print("The string does not contain the letter.")
# Out:
# Enter a string: letter
# Enter a letter to find: a
# The string does not contain the letter.

# %% [markdown]
# Ex 5: Write a program in which you have a list that contains seven integers that can be 0 or 1. Find the first zero entry in the list and change it to a 1. If there are no zero entries, print a message saying so.

# %%
# create a list
numbers = [1, 1, 1, 0, 1, 0, 1]

found_zero = False

# find the frist zero
for i in range(len(numbers)):
  if numbers[i] == 0:
    # change it into 1
    numbers[i] = 1
    # mark the flag as True
    found_zero = True


if found_zero:
  print(f"Changed the list: {numbers}")

else:
  print("There are no zero entries")
# Out:
# Changed the list: [1, 1, 1, 1, 1, 1, 1]
